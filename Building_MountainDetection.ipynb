# %%
import glob
import os

# Set the current working directory to where the notebook is located
notebook_dir = os.path.abspath('')
os.chdir(notebook_dir)

# Define paths to the dataset
dataset_dir = os.path.join(notebook_dir, 'building_dataset')

# If the dataset folder contains 'train' and 'test' subfolders
train_x = sorted(glob.glob(os.path.join(dataset_dir, 'train', '*_image.tif')))
train_y = sorted(glob.glob(os.path.join(dataset_dir, 'train', '*_label.tif')))
test_x = sorted(glob.glob(os.path.join(dataset_dir, 'test', '*_image.tif')))
test_y = sorted(glob.glob(os.path.join(dataset_dir, 'test', '*_label.tif')))

print(len(train_x), len(test_x))
# Out:
# 70 30

# %% [markdown]
# ## Data preprocessing

# %%
# converting training image to numpy array
train_xx = np.zeros((70, 128, 128, 3))
train_yy = np.zeros((70, 128, 128, 1))
for i, (img, mask) in enumerate(zip(train_x, train_y)):
  # if i == 1:
  #   break

  img = Image.open(img)
  np_img = np.array(img)
  train_xx[i] = np_img

  mask = Image.open(mask)
  np_mask = np.array(mask).reshape(128, 128, 1)
  train_yy[i] = np_mask

# %%
# converting training image to numpy array
test_xx = np.zeros((30, 128, 128, 3))
test_yy = np.zeros((30, 128, 128, 1))
for i, (img, mask) in enumerate(zip(test_x, test_y)):

  img = Image.open(img)
  np_img = np.array(img)
  test_xx[i] = np_img

  mask = Image.open(mask)
  np_mask = np.array(mask).reshape(128, 128, 1)
  test_yy[i] = np_mask

# %%
# Let's plot a sample input RGB image and output image with buildings

plt.imshow(train_xx[20, :, :, :].astype('uint8'))
plt.show()
plt.imshow(train_yy[20, :, :, 0].astype('uint8'))
plt.show()

# %% [markdown]
# ## Save to numpy format

# %%
train_xx.shape
# Out:
# (70, 128, 128, 3)

# %%
np.save('train_xx.npy', train_xx)
np.save('train_yy.npy', train_yy)
np.save("test_xx.npy", test_xx)
np.save("test_yy.npy", test_yy)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, Concatenate, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# Input
x_in = Input(shape=(128, 128, 3))

# Encoder
x_temp = Conv2D(32, (3, 3), activation='relu', padding='same')(x_in)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip1 = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = MaxPooling2D((2,2))(x_skip1)
x_temp = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip2 = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = MaxPooling2D((2,2))(x_skip2)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip3 = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = MaxPooling2D((2,2))(x_skip3)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)

# Decoder
x_temp = Conv2DTranspose(64, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(64, (3, 3), strides=(2, 2), activation='relu',  padding='same')(x_temp)
x_temp = Concatenate()([x_temp, x_skip3])
x_temp = Conv2DTranspose(64, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(64, (3, 3), strides=(2, 2), activation='relu',  padding='same')(x_temp)
x_temp = Concatenate()([x_temp, x_skip2])
x_temp = Conv2DTranspose(32, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(32, (3, 3), strides=(2, 2), activation='relu',  padding='same')(x_temp)
x_temp = Concatenate()([x_temp, x_skip1])
x_temp = Conv2DTranspose(32, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(32, (3, 3), activation='relu',  padding='same')(x_temp)

# Output layer
x_temp = Conv2D(32, (1, 1), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Conv2D(32, (1, 1), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_out = Conv2D(1, (1, 1), activation='sigmoid', padding='same')(x_temp)

# Model compilation
model = Model(inputs=x_in, outputs=x_out)

# Compile the model with Adam optimizer and mean squared error loss
optimizer = Adam(lr=0.001)
# Compile the model with Adam optimizer, mean squared error loss, and mean absolute error as a metric
model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])

# Print model summary
model.summary()

# Early stopping callback
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  dropout (Dropout)              (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   9248        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 64, 64, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 16, 16, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 64)   36928       ['dropout_3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 64)  36928       ['conv2d_7[0][0]']
#  ose)
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_transpose[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 16, 16, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  36928       ['dropout_4[0][0]']
#  spose)
#
#  concatenate (Concatenate)      (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 64)  73792       ['concatenate[0][0]']
#  spose)
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_transpose_2[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 32, 32, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 64)  36928       ['dropout_5[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 96)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 32)  27680       ['concatenate_1[0][0]']
#  spose)
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_transpose_4[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 64, 64, 32)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 32  9248       ['dropout_6[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_5[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 32  18464      ['concatenate_2[0][0]']
#  spose)                         )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 32  128        ['conv2d_transpose_6[0][0]']
#  rmalization)                   )
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 128, 128, 32  9248       ['dropout_7[0][0]']
#  spose)                         )
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 32  1056        ['conv2d_transpose_7[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 32  128        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 32  1056        ['batch_normalization_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 32  128        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 1)  33          ['batch_normalization_9[0][0]']
#
# ==================================================================================================
# Total params: 411,073
# Trainable params: 410,177
# Non-trainable params: 896
# __________________________________________________________________________________________________
# C:\Softwares\envs\py310\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Training model
history = model.fit(train_xx, train_yy, 
                    validation_data=(test_xx, test_yy), 
                    epochs=100, 
                    batch_size=10, 
                    verbose=1)


# Plotting loss and accuracy
import matplotlib.pyplot as plt

def plot_metrics(history):
    # Plot loss
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy if available
    if 'accuracy' in history.history:
        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title('Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Call the function passing the training history object
plot_metrics(history)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 8s 162ms/step - loss: 0.2446 - accuracy: 0.6356 - val_loss: 0.7625 - val_accuracy: 0.2316
# Epoch 2/100
# 7/7 [==============================] - 0s 60ms/step - loss: 0.1940 - accuracy: 0.7624 - val_loss: 0.7683 - val_accuracy: 0.2316
# Epoch 3/100
# 7/7 [==============================] - 0s 62ms/step - loss: 0.1607 - accuracy: 0.8108 - val_loss: 0.7682 - val_accuracy: 0.2316
# Epoch 4/100
# 7/7 [==============================] - 0s 61ms/step - loss: 0.1391 - accuracy: 0.8382 - val_loss: 0.7682 - val_accuracy: 0.2316
# Epoch 5/100
# 7/7 [==============================] - 0s 66ms/step - loss: 0.1184 - accuracy: 0.8616 - val_loss: 0.7675 - val_accuracy: 0.2316
# Epoch 6/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.1033 - accuracy: 0.8775 - val_loss: 0.7477 - val_accuracy: 0.2370
# Epoch 7/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0924 - accuracy: 0.8891 - val_loss: 0.6043 - val_accuracy: 0.3241
# Epoch 8/100
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0848 - accuracy: 0.8965 - val_loss: 0.5479 - val_accuracy: 0.3779
# Epoch 9/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0804 - accuracy: 0.9009 - val_loss: 0.4364 - val_accuracy: 0.4954
# Epoch 10/100
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0753 - accuracy: 0.9065 - val_loss: 0.3723 - val_accuracy: 0.5685
# Epoch 11/100
# 7/7 [==============================] - 0s 62ms/step - loss: 0.0720 - accuracy: 0.9096 - val_loss: 0.3628 - val_accuracy: 0.5817
# Epoch 12/100
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0693 - accuracy: 0.9127 - val_loss: 0.2164 - val_accuracy: 0.7364
# Epoch 13/100
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0666 - accuracy: 0.9152 - val_loss: 0.1248 - val_accuracy: 0.8481
# Epoch 14/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0660 - accuracy: 0.9159 - val_loss: 0.1152 - val_accuracy: 0.8608
# Epoch 15/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0634 - accuracy: 0.9187 - val_loss: 0.0818 - val_accuracy: 0.8982
# Epoch 16/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0620 - accuracy: 0.9202 - val_loss: 0.0725 - val_accuracy: 0.9072
# Epoch 17/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0604 - accuracy: 0.9224 - val_loss: 0.0736 - val_accuracy: 0.9082
# Epoch 18/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0626 - accuracy: 0.9190 - val_loss: 0.0721 - val_accuracy: 0.9074
# Epoch 19/100
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0595 - accuracy: 0.9226 - val_loss: 0.0812 - val_accuracy: 0.8924
# Epoch 20/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0576 - accuracy: 0.9250 - val_loss: 0.0691 - val_accuracy: 0.9101
# Epoch 21/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0565 - accuracy: 0.9263 - val_loss: 0.0670 - val_accuracy: 0.9126
# Epoch 22/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0538 - accuracy: 0.9296 - val_loss: 0.0720 - val_accuracy: 0.9055
# Epoch 23/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0538 - accuracy: 0.9296 - val_loss: 0.0621 - val_accuracy: 0.9167
# Epoch 24/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0538 - accuracy: 0.9292 - val_loss: 0.0677 - val_accuracy: 0.9079
# Epoch 25/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0531 - accuracy: 0.9303 - val_loss: 0.0665 - val_accuracy: 0.9093
# Epoch 26/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0529 - accuracy: 0.9307 - val_loss: 0.0592 - val_accuracy: 0.9200
# Epoch 27/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0509 - accuracy: 0.9329 - val_loss: 0.0669 - val_accuracy: 0.9071
# Epoch 28/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0507 - accuracy: 0.9332 - val_loss: 0.0623 - val_accuracy: 0.9144
# Epoch 29/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0503 - accuracy: 0.9336 - val_loss: 0.0618 - val_accuracy: 0.9148
# Epoch 30/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0492 - accuracy: 0.9351 - val_loss: 0.0597 - val_accuracy: 0.9177
# Epoch 31/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0485 - accuracy: 0.9362 - val_loss: 0.0612 - val_accuracy: 0.9146
# Epoch 32/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0475 - accuracy: 0.9373 - val_loss: 0.0582 - val_accuracy: 0.9206
# Epoch 33/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0482 - accuracy: 0.9363 - val_loss: 0.0561 - val_accuracy: 0.9239
# Epoch 34/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0470 - accuracy: 0.9375 - val_loss: 0.0623 - val_accuracy: 0.9138
# Epoch 35/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0480 - accuracy: 0.9364 - val_loss: 0.0571 - val_accuracy: 0.9227
# Epoch 36/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0470 - accuracy: 0.9376 - val_loss: 0.0592 - val_accuracy: 0.9195
# Epoch 37/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0451 - accuracy: 0.9401 - val_loss: 0.0576 - val_accuracy: 0.9219
# Epoch 38/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0463 - accuracy: 0.9385 - val_loss: 0.0589 - val_accuracy: 0.9220
# Epoch 39/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0448 - accuracy: 0.9407 - val_loss: 0.0592 - val_accuracy: 0.9211
# Epoch 40/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0455 - accuracy: 0.9394 - val_loss: 0.0578 - val_accuracy: 0.9229
# Epoch 41/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0467 - accuracy: 0.9379 - val_loss: 0.0549 - val_accuracy: 0.9271
# Epoch 42/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0461 - accuracy: 0.9388 - val_loss: 0.0613 - val_accuracy: 0.9177
# Epoch 43/100
# 7/7 [==============================] - 0s 73ms/step - loss: 0.0439 - accuracy: 0.9414 - val_loss: 0.0561 - val_accuracy: 0.9243
# Epoch 44/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0451 - accuracy: 0.9402 - val_loss: 0.0588 - val_accuracy: 0.9217
# Epoch 45/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0441 - accuracy: 0.9414 - val_loss: 0.0567 - val_accuracy: 0.9240
# Epoch 46/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0424 - accuracy: 0.9434 - val_loss: 0.0568 - val_accuracy: 0.9249
# Epoch 47/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0421 - accuracy: 0.9437 - val_loss: 0.0552 - val_accuracy: 0.9262
# Epoch 48/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0423 - accuracy: 0.9436 - val_loss: 0.0563 - val_accuracy: 0.9256
# Epoch 49/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0414 - accuracy: 0.9449 - val_loss: 0.0570 - val_accuracy: 0.9238
# Epoch 50/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0415 - accuracy: 0.9446 - val_loss: 0.0548 - val_accuracy: 0.9273
# Epoch 51/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0415 - accuracy: 0.9445 - val_loss: 0.0543 - val_accuracy: 0.9285
# Epoch 52/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0413 - accuracy: 0.9449 - val_loss: 0.0554 - val_accuracy: 0.9266
# Epoch 53/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0412 - accuracy: 0.9452 - val_loss: 0.0541 - val_accuracy: 0.9288
# Epoch 54/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0409 - accuracy: 0.9454 - val_loss: 0.0572 - val_accuracy: 0.9246
# Epoch 55/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0422 - accuracy: 0.9438 - val_loss: 0.0541 - val_accuracy: 0.9284
# Epoch 56/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0422 - accuracy: 0.9434 - val_loss: 0.0557 - val_accuracy: 0.9268
# Epoch 57/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0407 - accuracy: 0.9453 - val_loss: 0.0563 - val_accuracy: 0.9259
# Epoch 58/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0415 - accuracy: 0.9442 - val_loss: 0.0558 - val_accuracy: 0.9267
# Epoch 59/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0408 - accuracy: 0.9452 - val_loss: 0.0568 - val_accuracy: 0.9262
# Epoch 60/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0420 - accuracy: 0.9439 - val_loss: 0.0546 - val_accuracy: 0.9285
# Epoch 61/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0413 - accuracy: 0.9447 - val_loss: 0.0555 - val_accuracy: 0.9280
# Epoch 62/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0408 - accuracy: 0.9451 - val_loss: 0.0548 - val_accuracy: 0.9279
# Epoch 63/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0405 - accuracy: 0.9461 - val_loss: 0.0551 - val_accuracy: 0.9280
# Epoch 64/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0396 - accuracy: 0.9471 - val_loss: 0.0551 - val_accuracy: 0.9281
# Epoch 65/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0395 - accuracy: 0.9470 - val_loss: 0.0556 - val_accuracy: 0.9270
# Epoch 66/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0387 - accuracy: 0.9481 - val_loss: 0.0543 - val_accuracy: 0.9282
# Epoch 67/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0380 - accuracy: 0.9490 - val_loss: 0.0562 - val_accuracy: 0.9264
# Epoch 68/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0380 - accuracy: 0.9489 - val_loss: 0.0589 - val_accuracy: 0.9219
# Epoch 69/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0381 - accuracy: 0.9488 - val_loss: 0.0544 - val_accuracy: 0.9281
# Epoch 70/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0379 - accuracy: 0.9494 - val_loss: 0.0545 - val_accuracy: 0.9290
# Epoch 71/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0375 - accuracy: 0.9496 - val_loss: 0.0522 - val_accuracy: 0.9313
# Epoch 72/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0381 - accuracy: 0.9491 - val_loss: 0.0529 - val_accuracy: 0.9304
# Epoch 73/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0375 - accuracy: 0.9500 - val_loss: 0.0552 - val_accuracy: 0.9275
# Epoch 74/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0375 - accuracy: 0.9499 - val_loss: 0.0567 - val_accuracy: 0.9255
# Epoch 75/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0370 - accuracy: 0.9505 - val_loss: 0.0533 - val_accuracy: 0.9298
# Epoch 76/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0371 - accuracy: 0.9503 - val_loss: 0.0540 - val_accuracy: 0.9290
# Epoch 77/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0369 - accuracy: 0.9507 - val_loss: 0.0535 - val_accuracy: 0.9300
# Epoch 78/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0376 - accuracy: 0.9497 - val_loss: 0.0531 - val_accuracy: 0.9305
# Epoch 79/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0367 - accuracy: 0.9510 - val_loss: 0.0551 - val_accuracy: 0.9281
# Epoch 80/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0371 - accuracy: 0.9503 - val_loss: 0.0537 - val_accuracy: 0.9302
# Epoch 81/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0372 - accuracy: 0.9501 - val_loss: 0.0545 - val_accuracy: 0.9287
# Epoch 82/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0360 - accuracy: 0.9518 - val_loss: 0.0554 - val_accuracy: 0.9273
# Epoch 83/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0362 - accuracy: 0.9516 - val_loss: 0.0558 - val_accuracy: 0.9265
# Epoch 84/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0374 - accuracy: 0.9499 - val_loss: 0.0558 - val_accuracy: 0.9260
# Epoch 85/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0355 - accuracy: 0.9523 - val_loss: 0.0550 - val_accuracy: 0.9270
# Epoch 86/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0355 - accuracy: 0.9522 - val_loss: 0.0555 - val_accuracy: 0.9268
# Epoch 87/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0365 - accuracy: 0.9512 - val_loss: 0.0527 - val_accuracy: 0.9309
# Epoch 88/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0353 - accuracy: 0.9524 - val_loss: 0.0526 - val_accuracy: 0.9311
# Epoch 89/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0359 - accuracy: 0.9517 - val_loss: 0.0554 - val_accuracy: 0.9281
# Epoch 90/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0352 - accuracy: 0.9524 - val_loss: 0.0524 - val_accuracy: 0.9312
# Epoch 91/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0346 - accuracy: 0.9536 - val_loss: 0.0540 - val_accuracy: 0.9295
# Epoch 92/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0362 - accuracy: 0.9518 - val_loss: 0.0538 - val_accuracy: 0.9295
# Epoch 93/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0346 - accuracy: 0.9534 - val_loss: 0.0517 - val_accuracy: 0.9325
# Epoch 94/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0362 - accuracy: 0.9517 - val_loss: 0.0533 - val_accuracy: 0.9305
# Epoch 95/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0344 - accuracy: 0.9539 - val_loss: 0.0545 - val_accuracy: 0.9281
# Epoch 96/100
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0347 - accuracy: 0.9533 - val_loss: 0.0519 - val_accuracy: 0.9322
# Epoch 97/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0353 - accuracy: 0.9526 - val_loss: 0.0590 - val_accuracy: 0.9228
# Epoch 98/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0348 - accuracy: 0.9530 - val_loss: 0.0535 - val_accuracy: 0.9301
# Epoch 99/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0342 - accuracy: 0.9540 - val_loss: 0.0547 - val_accuracy: 0.9283
# Epoch 100/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0358 - accuracy: 0.9516 - val_loss: 0.0519 - val_accuracy: 0.9317

# %%
def plot_metrics(history):
    # Plot loss
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy if available
    if 'accuracy' in history.history:
        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title('Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Call the function passing the training history object
plot_metrics(history)

# %% [markdown]
# # Prediction

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_predictions(pred, actual, indices=None, threshold=0.5, save_path=None):
    """
    Plot predicted and actual values.

    Parameters:
    - pred: Predicted values.
    - actual: Actual values.
    - indices: List of indices to visualize (default is None, which plots randomly selected indices).
    - threshold: Threshold for binarizing predictions (default is 0.5).
    - save_path: Path to save the plots as images (default is None, which does not save).
    """
    if indices is None:
        indices = np.random.choice(pred.shape[0], size=min(3, pred.shape[0]), replace=False)

    for idx in indices:
        # Binarize predictions using threshold
        pred_bin = (pred[idx] > threshold).astype(np.uint8)

        # Create figure and subplots
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # Plot predicted values
        im_pred = axs[0].imshow(pred_bin[:, :, 0], cmap='gray')
        axs[0].set_title(f'Predicted (Sample {idx})')
        axs[0].axis('off')
        plt.colorbar(im_pred, ax=axs[0], fraction=0.046, pad=0.04)

        # Plot actual values
        im_actual = axs[1].imshow(actual[idx, :, :, 0], cmap='gray')
        axs[1].set_title(f'Actual (Sample {idx})')
        axs[1].axis('off')
        plt.colorbar(im_actual, ax=axs[1], fraction=0.046, pad=0.04)

        # Save plot if save_path is provided
        if save_path is not None:
            plt.savefig(f'{save_path}/sample_{idx}.png')
            plt.close()
        else:
            plt.show()

# Example usage:
plot_predictions(pred_test, test_yy, indices=[0, 1, 2], threshold=threshold, save_path=None)

# %% [markdown]
# This is not an operational model with high accuracy. But with more layers and with more data, we can develop this architecture in to an operational model with high accuracy.

# %% [markdown]
# ## Convert numpy array to image

# %%
from PIL import Image
import os
def convert_numpy_array_to_img(in_npy, out_folder, channel=3):
    n = in_npy.shape[0]
    for i in range(n):
        if channel==3:
            image = Image.fromarray(in_npy[i].astype('uint8'))
            image.save(os.path.join(out_folder, f"{i}_image.tif"))

        else:
            image = Image.fromarray(in_npy[i, :, :, 0])
            image.save(os.path.join(out_folder, f"{i}_label.tif"))

# %%
import os
import cv2

def convert_numpy_array_to_img(array, folder, channel=3):
    """
    Convert numpy array to image and save it in the specified folder.

    Parameters:
    - array: Numpy array representing the image data.
    - folder: Folder path where the image will be saved.
    - channel: Number of channels in the image (default is 3 for RGB).

    """
    # Create folder if it doesn't exist
    if not os.path.exists(folder):
        os.makedirs(folder)
    
    for i in range(array.shape[0]):
        # Construct file path
        file_path = os.path.join(folder, f'image_{i}.png')

        # Convert numpy array to image
        if channel == 1:
            img = array[i, :, :, 0]
        else:
            img = array[i]
        
        # Scale pixel values to 0-255
        img = img * 255.0
        img = img.astype('uint8')

        # Save image
        cv2.imwrite(file_path, img)

# Convert numpy arrays to images and save them
convert_numpy_array_to_img(x_train, 'train')
convert_numpy_array_to_img(y_train, 'train', channel=1)

convert_numpy_array_to_img(x_test, 'test')
convert_numpy_array_to_img(y_test, 'test', channel=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 36
#      33         cv2.imwrite(file_path, img)
#      35 # Convert numpy arrays to images and save them
# ---> 36 convert_numpy_array_to_img(x_train, 'train')
#      37 convert_numpy_array_to_img(y_train, 'train', channel=1)
#      39 convert_numpy_array_to_img(x_test, 'test')
#
# NameError: name 'x_train' is not defined
